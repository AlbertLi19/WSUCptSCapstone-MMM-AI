# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import os, glob
from scipy import ndimage, misc
import math

# %%
scale_path= r'C:\Users\Handwriting\Desktop\Dheeraj\HEMI\Main_Files\Crack_speed_evaluation\Scale.tiff'

# %%
scale_img= cv2.imread(scale_path)
plt.imshow(scale_img)
plt.show()

# %%
import numpy as np
import cv2
y=180
x=250
h=250
w=400
crop = scale_img[y:y+h, x:x+w]
plt.imshow(crop)
plt.show()

# %%
# import cv2
# import numpy as np

# # Load image, grayscale, Gaussian blur, threshold
# # gray = cv2.cvtColor(crop, cv2.COLOR_BGR2GRAY)
# blur = cv2.GaussianBlur(gray, (3,3), 0)
# thresh = cv2.threshold(blur, 200, 255, cv2.THRESH_BINARY_INV)[1]

# # Find contours
# cnts = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
# cnts = cnts[0] if len(cnts) == 2 else cnts[1]
# c = max(cnts, key=cv2.contourArea)

# # Obtain outer coordinates
# left = tuple(c[c[:, :, 0].argmin()][0])
# right = tuple(c[c[:, :, 0].argmax()][0])
# top = tuple(c[c[:, :, 1].argmin()][0])
# bottom = tuple(c[c[:, :, 1].argmax()][0])

# # Draw dots onto image
# cv2.drawContours(crop, [c], -1, (36, 255, 12), 2)
# cv2.circle(crop, left, 8, (0, 50, 255), -1)
# cv2.circle(crop, right, 8, (0, 255, 255), -1)
# cv2.circle(crop, top, 8, (255, 50, 0), -1)
# cv2.circle(crop, bottom, 8, (255, 255, 0), -1)

# print('left: {}'.format(left))
# print('right: {}'.format(right))
# print('top: {}'.format(top))
# print('bottom: {}'.format(bottom))
# plt.imshow(thresh)
# plt.show()
# plt.imshow(crop)
# plt.show()

# %%
gray = cv2.cvtColor(crop, cv2.COLOR_BGR2GRAY)
blur = cv2.GaussianBlur(gray, (7,7), 0)
thresh = cv2.threshold(blur, 130, 255, cv2.THRESH_BINARY)[1]
plt.imshow(thresh,cmap='gray')

# %%
# Find contours
cnts = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# %%
# Obtain outer coordinates
for c in cnts[0]:
    left = tuple(c[c[:, :, 0].argmin()][0])
    right = tuple(c[c[:, :, 0].argmax()][0])
    top = tuple(c[c[:, :, 1].argmin()][0])
    bottom = tuple(c[c[:, :, 1].argmax()][0])
    print(left, right,top, bottom)
# Out:
# (17, 43) (149, 55) (116, 39) (19, 56)
# (17, 10) (149, 23) (32, 8) (19, 25)

# %% [markdown]
# ### From above distances from top extremes of two contours we get 31 pixels distance: therefore
# ### 31 pixels== 0.1mm
# ### Hance: 1 pixel== (0.1/31)mm

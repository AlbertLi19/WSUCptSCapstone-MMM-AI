# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Handwriting\\Desktop\\Dheeraj\\HEMI\\Python_Scripts'

# %%
path= "C:\\Users\\Handwriting\\Desktop\\Dheeraj\\HEMI\\Main_Files\\Small_Carbon"

# %%
list_folders=  os.listdir(path)
list_folders
# Out:
# ['61620A_IP09_07_01_2022',
#  '61620A_TP10_07_01_2022',
#  '61620B_IP08_07_01_2022',
#  '61620B_TP10_01_07_2022']

# %%
dir_name = path+'\\'+list_folders[3]
test = os.listdir(dir_name)

for item in test:
    if item.endswith(".hdr"):
        os.remove(os.path.join(dir_name, item))
